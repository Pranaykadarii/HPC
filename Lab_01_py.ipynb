# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranaykadarii/HPC/blob/main/Lab_01_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Serial_baseline.py

# %%
import time, os, platform, sys
def work(n=5_000_00): #~500k iteration
  s=0.0
  for i in range(n):
    s+=(i%7)*0.123456
    return s
if __name__ == "_main_":
  print("hello from Hpc cluster!")
print("user:",os.getenv("USER"))
print("host:",platform.node())
print("python:",sys.version)
print("=== Work ===")
t0 = time.perf_counter()
result = work()
t1= time.perf_counter()
print(f"result={result:.6f} | time={(t1-t0):.3f} s")
# Out:
# user: None
# host: 3cb5f58f18ba
# python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# === Work ===
# result=0.000000 | time=0.000 s

# %%
import os,time,random

# %%
import os
import time
import random


def estimate_pi(n_samples, seed=42):
    random.seed(seed)
    inside = 0

    for _ in range(n_samples):
        x = random.random()
        y = random.random()
        if x * x + y * y <= 1.0:
            inside += 1

    return 4.0 * inside / n_samples


if __name__ == "__main__":
    # read task index from SLURM / PBS
    tid = int(os.getenv("SLURM_ARRAY_TASK_ID",
                        os.getenv("PBS_ARRAYID", "0")))

    sizes = [50_000, 100_000, 200_000, 400_000, 800_000]
    n_samples = sizes[tid % len(sizes)]

    t0 = time.perf_counter()
    pi = estimate_pi(n_samples)
    t1 = time.perf_counter()

    print(f"TASKID={tid} N={n_samples} Pi≈{pi:.6f} Time={t1 - t0:.4f}s")
# Out:
# TASKID=0 N=50000 Pi≈3.134640 Time=0.0127s
